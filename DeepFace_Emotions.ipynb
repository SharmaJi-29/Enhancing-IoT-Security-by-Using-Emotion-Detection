# %%
import cv2
import matplotlib.pyplot as plt
from deepface import DeepFace

# %%
predictions = DeepFace.analyze(img3)
predictions
# Out:
# Action: race: 100%|██████████| 4/4 [00:01<00:00,  3.73it/s]
# [{'emotion': {'angry': 89.19364809989929,
#    'disgust': 0.003007841769431252,
#    'fear': 10.716789215803146,
#    'happy': 0.008618026913609356,
#    'sad': 0.07671620696783066,
#    'surprise': 0.0011043704034818802,
#    'neutral': 0.00011715205801010597},
#   'dominant_emotion': 'angry',
#   'region': {'x': 38,
#    'y': 23,
#    'w': 59,
#    'h': 59,
#    'left_eye': None,
#    'right_eye': None},
#   'face_confidence': 0.88,
#   'age': 24,
#   'gender': {'Woman': 1.5637191097539471e-06, 'Man': 100.0},
#   'dominant_gender': 'Man',
#   'race': {'asian': 0.42779226787388325,
#    'indian': 4.500201717019081,
#    'black': 0.20130958873778582,
#    'white': 38.38711977005005,
#    'middle eastern': 36.25595271587372,
#    'latino hispanic': 20.227621495723724},
#   'dominant_race': 'white'}]

# %%
type(predictions)
# Out:
# list

# %%
predictions[0]['dominant_emotion']
# Out:
# 'angry'

# %%
face_classifier = cv2.CascadeClassifier(cv2.data.haarcascades + 'haarcascade_frontalface_default.xml')

# %%
gray = cv2.cvtColor(img3, cv2.COLOR_BGR2GRAY)
faces = face_classifier.detectMultiScale(gray, 1.1, 5)

for (x, y, w, h) in faces:
    center_coordinates = (x + w // 2, y + h // 2)
    radius = max(w // 2, h // 2)
    cv2.circle(img3, center_coordinates, radius, (0, 255, 0), 2)

# %%
plt.imshow(cv2.cvtColor(img3, cv2.COLOR_BGR2RGB))

# %%
font = cv2.FONT_HERSHEY_SIMPLEX

cv2.putText(img3,
            predictions[0]['dominant_emotion'],
            (0, 30),
            font, 1,
            (0, 0, 255),
            2,
            cv2.LINE_8)
# Out:
# array([[[231, 228, 223],
#         [235, 232, 227],
#         [238, 235, 230],
#         ...,
#         [228, 225, 221],
#         [235, 232, 228],
#         [235, 232, 228]],
#
#        [[239, 236, 231],
#         [244, 241, 236],
#         [249, 246, 241],
#         ...,
#         [244, 241, 237],
#         [251, 248, 244],
#         [252, 249, 245]],
#
#        [[236, 235, 231],
#         [242, 241, 237],
#         [248, 247, 243],
#         ...,
#         [245, 243, 242],
#         [254, 252, 251],
#         [255, 253, 252]],
#
#        ...,
#
#        [[255, 243, 239],
#         [217, 202, 199],
#         [ 79,  59,  54],
#         ...,
#         [210, 195, 179],
#         [134, 111,  95],
#         [101,  76,  60]],
#
#        [[251, 239, 233],
#         [213, 199, 193],
#         [ 73,  54,  49],
#         ...,
#         [209, 193, 180],
#         [131, 110,  95],
#         [ 97,  74,  59]],
#
#        [[250, 237, 229],
#         [214, 201, 193],
#         [109,  93,  86],
# ...

# %%
plt.imshow(cv2.cvtColor(img3, cv2.COLOR_BGR2RGB))

# %%
img2 = cv2.imread("surprized_man.jpeg")
img3 = cv2.imread("angry_man.jpeg")

# %%
plt.imshow(cv2.cvtColor(img3, cv2.COLOR_BGR2RGB))
